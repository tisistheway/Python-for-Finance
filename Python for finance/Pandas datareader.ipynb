# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import csv
import pandas_datareader as pdr
import datetime as dt

# %% [markdown]
# # Pandas datareader

# %%
ticker="SOL"
start=dt.datetime(2022,1,1)

# %%
start
# Out:
# datetime.datetime(2022, 1, 1, 0, 0)

# %%
data=pdr.get_data_yahoo(ticker,start)

# %%
data.head()
# Out:
#             High   Low  Open  Close   Volume  Adj Close
# Date
# 2021-12-31  6.21  5.95  5.95   5.96   914800       5.96
# 2022-01-03  6.22  5.93  6.08   6.15  1134900       6.15
# 2022-01-04  6.52  5.76  6.51   6.13  1997700       6.13
# 2022-01-05  6.72  6.10  6.19   6.17  2464200       6.17
# 2022-01-06  6.24  5.85  6.14   6.00  1450400       6.00

# %%
data.index
# Out:
# DatetimeIndex(['2021-12-31', '2022-01-03', '2022-01-04', '2022-01-05',
#                '2022-01-06', '2022-01-07', '2022-01-10', '2022-01-11',
#                '2022-01-12', '2022-01-13',
#                ...
#                '2022-10-03', '2022-10-04', '2022-10-05', '2022-10-06',
#                '2022-10-07', '2022-10-10', '2022-10-11', '2022-10-12',
#                '2022-10-13', '2022-10-14'],
#               dtype='datetime64[ns]', name='Date', length=199, freq=None)

# %%
data.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %%
data.tail()
# Out:
#             High   Low  Open  Close  Volume  Adj Close
# Date
# 2022-10-10  4.91  4.51  4.91   4.54  767400       4.54
# 2022-10-11  4.67  4.38  4.58   4.59  639700       4.59
# 2022-10-12  4.62  4.43  4.53   4.48  569800       4.48
# 2022-10-13  4.58  4.25  4.34   4.48  436000       4.48
# 2022-10-14  4.70  4.41  4.56   4.45  721900       4.45

# %%
end=dt.datetime(2021,12,31)

# %%
end
# Out:
# datetime.datetime(2021, 12, 31, 0, 0)

# %%
data.tail()
# Out:
#             High   Low  Open  Close  Volume  Adj Close
# Date
# 2022-10-10  4.91  4.51  4.91   4.54  767400       4.54
# 2022-10-11  4.67  4.38  4.58   4.59  639700       4.59
# 2022-10-12  4.62  4.43  4.53   4.48  569800       4.48
# 2022-10-13  4.58  4.25  4.34   4.48  436000       4.48
# 2022-10-14  4.70  4.41  4.56   4.45  721900       4.45

# %%
data.head()
# Out:
#             High   Low  Open  Close   Volume  Adj Close
# Date
# 2021-12-31  6.21  5.95  5.95   5.96   914800       5.96
# 2022-01-03  6.22  5.93  6.08   6.15  1134900       6.15
# 2022-01-04  6.52  5.76  6.51   6.13  1997700       6.13
# 2022-01-05  6.72  6.10  6.19   6.17  2464200       6.17
# 2022-01-06  6.24  5.85  6.14   6.00  1450400       6.00

# %%
data.tail()
# Out:
#             High   Low  Open  Close  Volume  Adj Close
# Date
# 2022-10-10  4.91  4.51  4.91   4.54  767400       4.54
# 2022-10-11  4.67  4.38  4.58   4.59  639700       4.59
# 2022-10-12  4.62  4.43  4.53   4.48  569800       4.48
# 2022-10-13  4.58  4.25  4.34   4.48  436000       4.48
# 2022-10-14  4.70  4.41  4.56   4.45  721900       4.45

# %%
nasdaq_symbos=pdr.get_nasdaq_symbols()

# %%
nasdaq_symbos
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Listed Funds Trust AAF First Priority CLO Bond...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
# ...               ...                                                ...
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZY               True                       Zymergen Inc. - Common Stock
# ZYME             True                       Zymeworks Inc. Common Shares
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# A                     N                  False           100.0       False
# AA                    N                  False           100.0       False
# AAA                   P                   True           100.0       False
# AAAU                  Z                   True           100.0       False
# AAC                   N                  False           100.0       False
# ...                 ...             ...    ...             ...         ...
# ZXZZT                 Q               G  False           100.0        True
# ZY                    Q               Q  False           100.0       False
# ZYME                  N                  False           100.0       False
# ZYNE                  Q               G  False           100.0       False
# ZYXI                  Q               Q  False           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# A                   NaN          A             A       False
# AA                  NaN         AA            AA       False
# AAA                 NaN        AAA           AAA       False
# AAAU                NaN       AAAU          AAAU       False
# AAC                 NaN        AAC           AAC       False
# ...                 ...        ...           ...         ...
# ZXZZT                 N        NaN         ZXZZT       False
# ZY                    N        NaN            ZY       False
# ZYME                NaN       ZYME          ZYME       False
# ZYNE                  N        NaN          ZYNE       False
# ZYXI                  N        NaN          ZYXI       False
#
# [12194 rows x 11 columns]

# %%
nasdaq_symbos.loc['AAPL']
# Out:
# Nasdaq Traded                            True
# Security Name       Apple Inc. - Common Stock
# Listing Exchange                            Q
# Market Category                             Q
# ETF                                     False
# Round Lot Size                          100.0
# Test Issue                              False
# Financial Status                            N
# CQS Symbol                                NaN
# NASDAQ Symbol                            AAPL
# NextShares                              False
# Name: AAPL, dtype: object

# %%
len(nasdaq_symbos)
# Out:
# 12194

# %%
nasdaq_symbos.head()
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Listed Funds Trust AAF First Priority CLO Bond...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# A                     N                  False           100.0       False
# AA                    N                  False           100.0       False
# AAA                   P                   True           100.0       False
# AAAU                  Z                   True           100.0       False
# AAC                   N                  False           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# A                   NaN          A             A       False
# AA                  NaN         AA            AA       False
# AAA                 NaN        AAA           AAA       False
# AAAU                NaN       AAAU          AAAU       False
# AAC                 NaN        AAC           AAC       False

# %%
nasdaq_symbos.head()
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Listed Funds Trust AAF First Priority CLO Bond...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# A                     N                  False           100.0       False
# AA                    N                  False           100.0       False
# AAA                   P                   True           100.0       False
# AAAU                  Z                   True           100.0       False
# AAC                   N                  False           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# A                   NaN          A             A       False
# AA                  NaN         AA            AA       False
# AAA                 NaN        AAA           AAA       False
# AAAU                NaN       AAAU          AAAU       False
# AAC                 NaN        AAC           AAC       False

# %%
len(nasdaq_symbos)
# Out:
# 12194
